# %% [markdown]
# <a href="https://colab.research.google.com/github/luzdayananoriegaperalta-cpu/Luz-dayana/blob/main/Confort_termico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Indice de confort termico para ganado vacuno**
#
# **Objetivo**
#
# Estimar indice de confort para la produccion de ganado en el departamento de Sucre como estrategia  de alerta a productores ganaderos con el fin de recomendar estrategias de adaptacion de cambio climatico en el marco de la expansion y proyeccion social del programa Ingenieria Agricola en la Universidad de Sucre desde el grupe de Bioindustrias.
#
#
# ##**Metodologia** ##
#
# para la predicción de índices de confort térmico con 3 días de anticipación se utilizarán los datos
# meteorológicos de IDEAM aplicando los modelos matemáticos para cada índice. Se realizará la
# espacialización de los índices en todo el departamento teniendo en cuenta métodos de
# variabilidad espacial y series de tiempo de los datos meteorológicos.
# Se crearán reportes diarios para alertar a los productores sobre el nivel de confort térmico de los
# animales y propondrán estrategias de adaptación al cambio climático para que no se vea afectado
# la productividad.

# %% [markdown]
# **Metodos y calculos**
#
# ##**Índice de temperatura y humedad (producción intensiva)** ##
#
# $$ITH = 0.72 * (T_bs + T_bh) + 40.6$$
#
# Donde:
#
# 1. T_$bs:$ Temperatura bulbo seco (°^oC)
# 2. T_$bs:$ Temperatura bulbo seco (°^oC)
#
# Para la correlación de los datos de la especie bovina en la producción de leche se recomienda
# utilizar los límites propuestos por National Weather Service:
#
# + Sí $ITH ≤ 70$ ambiente no estresante
#
# + Sí $ITH > 70 o ≤ 78$ situación de alerta por estrés térmico
#
# + Sí $ITH > 78 o ≤ 83$ peligro por estrés térmico
#
# + Sí $ITH > 83 $ situación crítica

# %%
# entrada: temperatura de bulbo seco (tbs), grados centigrados
# temperatura de bulbo humedo (tbh), grados centigrados
tbs = float(input("ingrese la temperatura bulbo seco, grados centigrados:"))
tbh = float (input ("ingrese la temperatura bulbo humedo, grados centigrados:"))

#proceso: calculo de ith
ith = 0.72* (tbs + tbh ) + 40.6

# salida: ith
if ith <= 70:
    print ("Ambiente no estresante")
elif ith > 70 and ith <= 78:
    print ("Situación de alerta por estrés térmico")
elif ith > 78 and ith <= 83:
    print ("Peligro por estrés térmico")
else:
    print ("Situación crítica")
# Out:
# ingrese la temperatura bulbo seco, grados centigrados:38
# ingrese la temperatura bulbo humedo, grados centigrados:37
# Situación crítica
