# %% [markdown]
# <a href="https://colab.research.google.com/github/luzdayananoriegaperalta-cpu/Luz-dayana/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Control de Rendimiento en Extracción de Aceite #
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento**
# Una planta procesadora de palma de aceite necesita  calcular.  **el Índice de Rendimiento de Extracción (IRE)**  El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# ##Requerimientos ##
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).
# 3. Solicitar los litros de aceite obtenidos (Tipo float).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L (r)
#
# $$Peso Aceite (kg)=Litros*0.92$$
#
# $$Rendimiento=(Peso Aceite/Peso Racimos)*100$$
#
# **Prueba del programa**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%

# %%
# Entrada: Ingresar solicitar el nombre del lote de producción (Tipo string).
# solicitar el peso de los racimos en kg (Tipo float). (pr)
# Solicitar los litrosceite obtenidos (Tipo float). (lt)

nombre = input("ingrese el nombre del lote: ")
pr = float(input("ingrese el peso de los racimos en kg: "))
lt = float(input("ingrese los litros de aceite obtenidos: "))

# Proceso: calcular peso del aceite (pr) y el rendimiento (r)
pa = lt*0.92
r = (pa/pr)*100
# Salida; informar el rendimiento del lote
print("el rendimiento del lote", nombre, "es del", r, "%")


# Salida: informar el rendimiento del lote
# Out:
# ingrese el nombre del lote: el perico
# ingrese el peso de los racimos en kg: 1000
# ingrese los litros de aceite obtenidos: 200
# el rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# ```markdown
# ## Explicación del Código del Problema de Rendimiento en Extracción de Aceite
#
# Este código solicita al usuario información sobre un lote de producción de aceite de palma, realiza cálculos y muestra el rendimiento de extracción.
#
# ```python
# # Entrada: Ingresar solicitar el nombre del lote de producción (Tipo string).
# # solicitar el peso de los racimos en kg (Tipo float). (pr)
# # Solicitar los litrosceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios que describen el propósito de las siguientes líneas de código: solicitar el nombre del lote, el peso de los racimos y los litros de aceite obtenidos.
#
# ```python
# nombre = input("ingrese el nombre del lote: ")
# ```
# Esta línea utiliza la función `input()` para pedir al usuario que ingrese el nombre del lote de producción. El texto entre comillas es el mensaje que se muestra al usuario. La entrada del usuario se guarda como una cadena de texto (string) en la variable `nombre`.
#
# ```python
# pr = float(input("ingrese el peso de los racimos en kg: "))
# ```
# Esta línea solicita al usuario el peso de los racimos en kilogramos. La función `input()` obtiene la entrada como una cadena. La función `float()` convierte esa cadena a un número de punto flotante (decimal), ya que el peso puede no ser un número entero. El resultado se guarda en la variable `pr`.
#
# ```python
# lt = float(input("ingrese los litros de aceite obtenidos: "))
# ```
# De manera similar a la línea anterior, esta línea solicita al usuario los litros de aceite obtenidos. La entrada se convierte a un número de punto flotante usando `float()` y se almacena en la variable `lt`.
#
# ```python
# # Proceso: calcular peso del aceite (pr) y el rendimiento (r)
# ```
# Este comentario indica que las siguientes líneas realizarán los cálculos necesarios.
#
# ```python
# pa = lt*0.92
# ```
# Esta línea calcula el peso del aceite (`pa`) multiplicando los litros de aceite (`lt`) por su densidad aproximada (0.92 kg/L). El resultado es el peso del aceite en kilogramos.
#
# ```python
# r = (pa/pr)*100
# ```
# Esta línea calcula el rendimiento (`r`). Se divide el peso del aceite (`pa`) entre el peso de los racimos (`pr`) y el resultado se multiplica por 100 para obtener un porcentaje. El rendimiento se guarda en la variable `r`.
#
# ```python
# # Salida; informar el rendimiento del lote
# ```
# Este comentario indica que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("el rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta línea utiliza la función `print()` para mostrar el resultado al usuario. Concatena varias cadenas de texto y las variables `nombre` y `r` para formar un mensaje informativo que incluye el nombre del lote y el rendimiento calculado.
#
# ```python
# # Salida: informar el rendimiento del lote
# ```
# Este es un comentario adicional que refuerza el propósito de la última línea de código.
# ```
