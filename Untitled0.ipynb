# %% [markdown]
# <a href="https://colab.research.google.com/github/luzdayananoriegaperalta-cpu/Luz-dayana/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar bibliotecas necesarias
import sympy as sp  # Para manipulación simbólica
import numpy as np  # Para cálculos numéricos
import matplotlib.pyplot as plt  # Para graficar

# Definir el punto de expansión de la serie de Taylor
x0 = 0  # Centro de la expansión
n = 5  # Serie de Taylor de orden (términos hasta x^4)

# Definir la variable simbólica
x = sp.Symbol('x')

# Obtener la serie de Taylor de cos(x) centrada en x0 con n términos
t = sp.exp(x).series(x, x0, n).removeO()
print(t)  # Imprimir la serie de Taylor

# Convertir la expresión simbólica en una función numérica usable con numpy
t = sp.lambdify(x, t, 'numpy')

# Generar valores de x para la gráfica
xx = np.linspace(x0 - 3, x0 + 3, 1000)  # Rango de valores de x

# Calcular los valores reales de e^x y su aproximación con la serie de Taylor
ye = np.exp(xx)  # Valores exactos de e^x
yt = t(xx)  # Valores aproximados con la serie de Taylor

# Graficar la función original y su aproximación
plt.plot(xx, ye, label="e^x")  # Gráfica de la función original
plt.plot(xx, yt, label="Serie de Taylor orden 4", linestyle="--")  # Gráfica de la aproximación

# Agregar leyenda y título
plt.legend()
plt.title("Serie de Taylor de $f(x) = $e^x$ (Cuarto orden)")

# Configuración adicional
plt.grid(False)  # Desactivar la cuadrícula

# Guardar la figura (opcional, descomentarlo si se necesita guardar)
# plt.savefig('seriet.pdf', bbox_inches='tight')

# Mostrar la gráfica
plt.show()
# Out:
# x**4/24 + x**3/6 + x**2/2 + x + 1

# %%
# Importar bibliotecas necesarias
import sympy as sp  # Para manipulación simbólica
import numpy as np  # Para cálculos numéricos
import matplotlib.pyplot as plt  # Para graficar

# Definir el punto de expansión de la serie de Taylor
x0 = 1  # Centro de la expansión (x0 = 1 para ln(x))
n = 6   # Serie de Taylor de quinto orden (terminos hasta orden 5)

# Definir la variable simbólica
x = sp.Symbol('x')

# Obtener la serie de Taylor de ln(x) centrada en x0 = 1
t = sp.log(x).series(x, x0, n).removeO()
print("Serie de Taylor obtenida:", t)

# Convertir la expresión simbólica en una función numérica usable con numpy
t = sp.lambdify(x, t, 'numpy')

# Generar valores de x para la gráfica (deben ser mayores a 0 para el logaritmo)
xx = np.linspace(0.1, 2.0, 1000)

# Calcular los valores reales de ln(x) y su aproximaciÃ³n
yln = np.log(xx)   # Valores exactos de ln(x)
yt = t_func(xx)    # Valores aproximados con la serie de Taylor

# Graficar la función original y su aproximación
plt.plot(xx, yln, label="ln(x)") # Gráfica de la función original
plt.plot(xx, yt, label="Serie de Taylor orden 5", linestyle="--") # Gráfica de la aproximación


# Agregar leyenda y título
plt.legend()
plt.title("Serie de Taylor de $f(x) = \ln(x)$ (Quinto orden, $x_0=1$)")

# Configuración adicional
plt.grid(False)  # Desactivar la cuadrícula

# Guardar la figura (opcional, descomentarlo si se necesita guardar)
# plt.savefig('seriet.pdf', bbox_inches='tight')

# Mostrar la gráfica
plt.show()
# Out:
# Serie de Taylor obtenida: x + (x - 1)**5/5 - (x - 1)**4/4 + (x - 1)**3/3 - (x - 1)**2/2 - 1
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_740/3536876501.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.title("Serie de Taylor de $f(x) = \ln(x)$ (Quinto orden, $x_0=1$)")
